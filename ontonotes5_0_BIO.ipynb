# %% [markdown]
# <a href="https://colab.research.google.com/github/dawudmq/OntoNotes-5.0-NER-BIO/blob/master/ontonotes5_0_BIO.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
cd /content/drive/MyDrive/Research records/ontonotes 5.0
# Out:
# /content/drive/MyDrive/Research records/ontonotes 5.0

# %%
# !sudo apt-get install git
# !git clone https://github.com/yuchenlin/OntoNotes-5.0-NER-BIO.git
# !git clone https://github.com/Raldir/Zero-shot-NERC.git

# !tar zxvf ontonotes-release-5.0_LDC2013T19-2019-05-30.tgz
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# git is already the newest version (1:2.17.1-1ubuntu0.10).
# 0 upgraded, 0 newly installed, 0 to remove and 40 not upgraded.

# %%
# !which python
# !python -V
# !wget -c https://repo.anaconda.com/miniconda/Miniconda2-py27_4.8.3-Linux-x86_64.sh
# !ls
# !chmod +x Miniconda2-py27_4.8.3-Linux-x86_64.sh

# %env PYTHONPATH=
# !./Miniconda2-py27_4.8.3-Linux-x86_64.sh -b -f -p /usr/local

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !which conda
# !conda --version
# !which python
# !python -V

import sys
_ = (sys.path.append("/usr/local/lib/python2.7/site-packages"))
# Out:
# /usr/local/bin/conda
# conda 4.9.2
# /usr/local/bin/python
# Python 3.7.9

# %%
import sys
sys.path

#!conda env list

# %%
# !conda create --name py27 python=2.7
# !source activate py27
# !conda install --channel defaults conda python=2.7.10 --yes
# Out:
# WARNING: A conda environment already exists at '/usr/local/envs/py27'
# Remove existing environment (y/[n])?
# CondaError: KeyboardInterrupt

# %%
# !source activate py27 && python -V
# Out:
# Python 2.7.18 :: Anaconda, Inc.

# %%
cd /content/drive/MyDrive/Research records/ontonotes 5.0/OntoNotes-5.0-NER-BIO
# Out:
# /content/drive/MyDrive/Research records/ontonotes 5.0/OntoNotes-5.0-NER-BIO

# %%
# !source activate py27 && /bin/bash ./conll-formatted-ontonotes-5.0/scripts/skeleton2conll.sh -D ../ontonotes-release-5.0/data/files/data ./conll-formatted-ontonotes-5.0
# Out:
# 流式输出内容被截断，只能显示最后 5000 行内容。
# -> python ./conll-formatted-ontonotes-5.0/scripts/skeleton2conll.py ../ontonotes-release-5.0/data/files/data/english/annotations/wb/sel/03/sel_0386.parse ./conll-formatted-ontonotes-5.0/data/train/data/english/annotations/wb/sel/03/sel_0386.gold_skel ./conll-formatted-ontonotes-5.0/data/train/data/english/annotations/wb/sel/03/sel_0386.gold_conll -edited --text
# -> python ./conll-formatted-ontonotes-5.0/scripts/skeleton2conll.py ../ontonotes-release-5.0/data/files/data/english/annotations/wb/sel/03/sel_0387.parse ./conll-formatted-ontonotes-5.0/data/train/data/english/annotations/wb/sel/03/sel_0387.gold_skel ./conll-formatted-ontonotes-5.0/data/train/data/english/annotations/wb/sel/03/sel_0387.gold_conll -edited --text
# ...
